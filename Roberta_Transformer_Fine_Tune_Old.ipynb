# %%
from datasets import Dataset
import pandas as pd

# %%
df = pd.read_csv('comprehensive_quotes.csv')

df = df[['Sentences', 'Stance']]
df.columns = ['text', 'label']
df.head(10)
dataset = Dataset.from_pandas(df)

# %%
tokenizer = AutoTokenizer.from_pretrained("roberta-base")

def tokenize(batch):
    return tokenizer(batch["text"], padding="max_length", truncation=True)

dataset = dataset.map(tokenize, batched=True)
# Out:
# Map: 100%|██████████| 242/242 [00:00<00:00, 5085.20 examples/s]

# %%
# !pip uninstall transformers Y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: transformers 4.35.2
# Uninstalling transformers-4.35.2:
#   Would remove:
#     /Users/wangcancan/miniconda3/envs/py312/bin/transformers-cli
#     /Users/wangcancan/miniconda3/envs/py312/lib/python3.12/site-packages/transformers-4.35.2.dist-info/*
#     /Users/wangcancan/miniconda3/envs/py312/lib/python3.12/site-packages/transformers/*
# Proceed (Y/n)? ^C

# %%
Y

# %%
from transformers import AutoModelForSequenceClassification, Trainer, TrainingArguments
from sklearn.utils.class_weight import compute_class_weight
import torch

model = AutoModelForSequenceClassification.from_pretrained("roberta-base", num_labels=2)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 from transformers import AutoModelForSequenceClassification, Trainer, TrainingArguments
#       2 from sklearn.utils.class_weight import compute_class_weight
#       3 import torch
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/transformers/utils/import_utils.py:2154, in _LazyModule.__getattr__(self, name)
#    2152 elif name in self._class_to_module.keys():
#    2153     try:
# -> 2154         module = self._get_module(self._class_to_module[name])
#    2155         value = getattr(module, name)
#    2156     except (ModuleNotFoundError, RuntimeError) as e:
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/transformers/utils/import_utils.py:2184, in _LazyModule._get_module(self, module_name)
#    2182     return importlib.import_module("." + module_name, self.__name__)
#    2183 except Exception as e:
# -> 2184     raise e
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/transformers/utils/import_utils.py:2182, in _LazyModule._get_module(self, module_name)
#    2180 def _get_module(self, module_name: str):
#    2181     try:
# -> 2182         return importlib.import_module("." + module_name, self.__name__)
#    2183     except Exception as e:
#    2184         raise e
#
# File ~/miniconda3/envs/py312/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/transformers/trainer.py:40
#      35 from typing import TYPE_CHECKING, Any, Callable, Dict, List, Optional, Tuple, Union
#      38 # Integrations must be imported before ML frameworks:
#      39 # isort: off
# ---> 40 from .integrations import (
#      41     get_reporting_integration_callbacks,
#      42     hp_params,
#      43 )
#      45 # isort: on
#      47 import huggingface_hub.utils as hf_hub_utils
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/transformers/utils/import_utils.py:2154, in _LazyModule.__getattr__(self, name)
#    2152 elif name in self._class_to_module.keys():
#    2153     try:
# -> 2154         module = self._get_module(self._class_to_module[name])
#    2155         value = getattr(module, name)
#    2156     except (ModuleNotFoundError, RuntimeError) as e:
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/transformers/utils/import_utils.py:2184, in _LazyModule._get_module(self, module_name)
#    2182     return importlib.import_module("." + module_name, self.__name__)
#    2183 except Exception as e:
# -> 2184     raise e
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/transformers/utils/import_utils.py:2182, in _LazyModule._get_module(self, module_name)
#    2180 def _get_module(self, module_name: str):
#    2181     try:
# -> 2182         return importlib.import_module("." + module_name, self.__name__)
#    2183     except Exception as e:
#    2184         raise e
#
# File ~/miniconda3/envs/py312/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/transformers/integrations/integration_utils.py:74
#      72 from ..trainer_utils import PREFIX_CHECKPOINT_DIR, BestRun, IntervalStrategy  # noqa: E402
#      73 from ..training_args import ParallelMode  # noqa: E402
# ---> 74 from ..utils import ENV_VARS_TRUE_VALUES, is_torch_tpu_available  # noqa: E402
#      77 # Integration functions:
#      78 def is_wandb_available():
#      79     # any value of WANDB_DISABLED disables wandb
#
# ImportError: cannot import name 'is_torch_tpu_available' from 'transformers.utils' (/Users/wangcancan/miniconda3/envs/py312/lib/python3.12/site-packages/transformers/utils/__init__.py)
